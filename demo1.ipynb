# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(-2,2,100)
y =np.exp(x)

# %%
plt.plot(x,y)
plt.annotate(text='point(0,1)',xy=(0,1),xytext=(0,3),arrowprops=dict(facecolor='blue', shrink=0.05))
plt.show()
